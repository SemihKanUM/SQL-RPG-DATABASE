# %%
run generate_data.py
# Out:
# questions (entity_type='dialogue') Table:
# +-----+---------------------------------------------------------------------------------------------------------------------------------------+----------------+---------+
# |  id |                                                                content                                                                | choice_options | emotion |
# +-----+---------------------------------------------------------------------------------------------------------------------------------------+----------------+---------+
# |  1  |                            Yo, fam! Don't forget to like and subscribe before you head to the Dark Forest!                            |      535       |   539   |
# |  3  |                        To defeat your enemies, you must know them, train hard, and also buy some premium gems.                        |      210       |   644   |
# ...
